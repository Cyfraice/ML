# %% [markdown]
# <a href="https://colab.research.google.com/github/Cyfraice/ML/blob/main/gpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
PROMPT = "How bed is a cat ?"
input_ids = tokenizer.encode(PROMPT, return_tensors='pt', add_special_tokens = True)
input_ids
# Out:
# tensor([[2437, 3996,  318,  257, 3797, 5633]])

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
output = model.generate(input_ids, max_length=100, no_repeat_ngram_size=2)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
generated_text = tokenizer.decode(output[0], add_special_tokens = True)
print(generated_text)
# Out:
# How bed is a cat?
#
# A cat is an animal that is not a human. It is the only animal in the world that can be considered a living being.
# . A cat can live in a house, a garden, or even in an apartment. The cat's body is covered with fur, and its eyes are covered in fur. Cats are not human, but they are animals that are considered to be human beings. They are also considered animals who are capable of being human and
